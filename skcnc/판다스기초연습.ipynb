# %%
import pandas as pd

# %%
data = {"시가":[980,200,300],"고가":[990,300,500], "저가":[920,180,300], "종가":[930,180,400] }
index = ["비트코인","리플","이더리움"]

df = pd.DataFrame(data, index)
df
# Out:
#        시가   고가   저가   종가
# 비트코인  980  990  920  930
# 리플    200  300  180  180
# 이더리움  300  500  300  400

# %%
# 데이터 불러오기
df["시가"]
# Out:
# 비트코인    980
# 리플      200
# 이더리움    300
# Name: 시가, dtype: int64

# %%
# 2개의 열 불러오기 
# []리스트 형태로 불러와야함

df[["시가","고가"]]
# Out:
#        시가   고가
# 비트코인  980  990
# 리플    200  300
# 이더리움  300  500

# %%
# 인덱스 이름으로 접근하기 위해서는 loc
# 행번호 접근하려면 iloc
df.loc["비트코인"]
# Out:
# 시가    980
# 고가    990
# 저가    920
# 종가    930
# Name: 비트코인, dtype: int64

# %%
df.iloc[0]
# Out:
# 시가    980
# 고가    990
# 저가    920
# 종가    930
# Name: 비트코인, dtype: int64

# %%
df.loc["비트코인":"이더리움"]
# Out:
#        시가   고가   저가   종가
# 비트코인  980  990  920  930
# 리플    200  300  180  180
# 이더리움  300  500  300  400

# %%
df.iloc[0:2]
# Out:
#        시가   고가   저가   종가
# 비트코인  980  990  920  930
# 리플    200  300  180  180

# %%
df.iloc[1:3,1:4]
# Out:
#        고가   저가   종가
# 리플    300  180  180
# 이더리움  500  300  400

# %%
import pyupbit
# Out:
# /Users/kimdasol/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df = pyupbit.get_ohlcv("KRW-BTC")

# %%
df.head()
# Out:
#                            open        high         low       close  \
# 2023-04-05 09:00:00  37207000.0  37804000.0  36948000.0  37139000.0
# 2023-04-06 09:00:00  37139000.0  37211000.0  36800000.0  37058000.0
# 2023-04-07 09:00:00  37058000.0  37200000.0  36890000.0  36993000.0
# 2023-04-08 09:00:00  36993000.0  37249000.0  36930000.0  37080000.0
# 2023-04-09 09:00:00  37064000.0  37576000.0  36878000.0  37313000.0
#
#                           volume         value
# 2023-04-05 09:00:00  4804.317546  1.798466e+11
# 2023-04-06 09:00:00  3265.195674  1.208360e+11
# 2023-04-07 09:00:00  2191.385527  8.117821e+10
# 2023-04-08 09:00:00  3044.987229  1.130097e+11
# 2023-04-09 09:00:00  3846.312156  1.428535e+11

# %%
df["range"] = df["high"] - df["low"]

# %%
df. head()
# Out:
#                            open        high         low       close  \
# 2023-04-05 09:00:00  37207000.0  37804000.0  36948000.0  37139000.0
# 2023-04-06 09:00:00  37139000.0  37211000.0  36800000.0  37058000.0
# 2023-04-07 09:00:00  37058000.0  37200000.0  36890000.0  36993000.0
# 2023-04-08 09:00:00  36993000.0  37249000.0  36930000.0  37080000.0
# 2023-04-09 09:00:00  37064000.0  37576000.0  36878000.0  37313000.0
#
#                           volume         value     range
# 2023-04-05 09:00:00  4804.317546  1.798466e+11  856000.0
# 2023-04-06 09:00:00  3265.195674  1.208360e+11  411000.0
# 2023-04-07 09:00:00  2191.385527  8.117821e+10  310000.0
# 2023-04-08 09:00:00  3044.987229  1.130097e+11  319000.0
# 2023-04-09 09:00:00  3846.312156  1.428535e+11  698000.0

# %%
# 데이터 컬럼 삭제하기
df2 = df.drop("volume", axis=1)

# %%
df2.head()
# Out:
#                            open        high         low       close  \
# 2023-04-05 09:00:00  37207000.0  37804000.0  36948000.0  37139000.0
# 2023-04-06 09:00:00  37139000.0  37211000.0  36800000.0  37058000.0
# 2023-04-07 09:00:00  37058000.0  37200000.0  36890000.0  36993000.0
# 2023-04-08 09:00:00  36993000.0  37249000.0  36930000.0  37080000.0
# 2023-04-09 09:00:00  37064000.0  37576000.0  36878000.0  37313000.0
#
#                             value     range
# 2023-04-05 09:00:00  1.798466e+11  856000.0
# 2023-04-06 09:00:00  1.208360e+11  411000.0
# 2023-04-07 09:00:00  8.117821e+10  310000.0
# 2023-04-08 09:00:00  1.130097e+11  319000.0
# 2023-04-09 09:00:00  1.428535e+11  698000.0

# %%
# 데이터 삭제를 원본에 적용하기 위해서는 inplace 사용
df.drop("volume", axis=1, inplace=True)

# %%
df.head()
# Out:
#                            open        high         low       close  \
# 2023-04-05 09:00:00  37207000.0  37804000.0  36948000.0  37139000.0
# 2023-04-06 09:00:00  37139000.0  37211000.0  36800000.0  37058000.0
# 2023-04-07 09:00:00  37058000.0  37200000.0  36890000.0  36993000.0
# 2023-04-08 09:00:00  36993000.0  37249000.0  36930000.0  37080000.0
# 2023-04-09 09:00:00  37064000.0  37576000.0  36878000.0  37313000.0
#
#                             value     range
# 2023-04-05 09:00:00  1.798466e+11  856000.0
# 2023-04-06 09:00:00  1.208360e+11  411000.0
# 2023-04-07 09:00:00  8.117821e+10  310000.0
# 2023-04-08 09:00:00  1.130097e+11  319000.0
# 2023-04-09 09:00:00  1.428535e+11  698000.0

# %%
date = "2023-10-25 09:00:00"
dt = pd.to_datetime(date)
dt
# Out:
# Timestamp('2023-10-25 09:00:00')

# %%
df.loc[dt]= [100,110,100,100,100,102]
df
# Out:
#                            open        high         low       close  \
# 2023-04-05 09:00:00  37207000.0  37804000.0  36948000.0  37139000.0
# 2023-04-06 09:00:00  37139000.0  37211000.0  36800000.0  37058000.0
# 2023-04-07 09:00:00  37058000.0  37200000.0  36890000.0  36993000.0
# 2023-04-08 09:00:00  36993000.0  37249000.0  36930000.0  37080000.0
# 2023-04-09 09:00:00  37064000.0  37576000.0  36878000.0  37313000.0
# ...                         ...         ...         ...         ...
# 2023-10-18 09:00:00  38652000.0  39380000.0  38479000.0  38710000.0
# 2023-10-19 09:00:00  38672000.0  39250000.0  38550000.0  39000000.0
# 2023-10-20 09:00:00  39000000.0  40700000.0  38820000.0  40250000.0
# 2023-10-21 09:00:00  40250000.0  40300000.0  39975000.0  40200000.0
# 2023-10-25 09:00:00       100.0       110.0       100.0       100.0
#
#                             value      range
# 2023-04-05 09:00:00  1.798466e+11   856000.0
# 2023-04-06 09:00:00  1.208360e+11   411000.0
# ...

# %%
df.drop(date, axis=0, inplace= True)
df
# Out:
#                            open        high         low       close  \
# 2023-04-05 09:00:00  37207000.0  37804000.0  36948000.0  37139000.0
# 2023-04-06 09:00:00  37139000.0  37211000.0  36800000.0  37058000.0
# 2023-04-07 09:00:00  37058000.0  37200000.0  36890000.0  36993000.0
# 2023-04-08 09:00:00  36993000.0  37249000.0  36930000.0  37080000.0
# 2023-04-09 09:00:00  37064000.0  37576000.0  36878000.0  37313000.0
# ...                         ...         ...         ...         ...
# 2023-10-17 09:00:00  38686000.0  38947000.0  38156000.0  38652000.0
# 2023-10-18 09:00:00  38652000.0  39380000.0  38479000.0  38710000.0
# 2023-10-19 09:00:00  38672000.0  39250000.0  38550000.0  39000000.0
# 2023-10-20 09:00:00  39000000.0  40700000.0  38820000.0  40250000.0
# 2023-10-21 09:00:00  40250000.0  40300000.0  39975000.0  40200000.0
#
#                             value      range
# 2023-04-05 09:00:00  1.798466e+11   856000.0
# 2023-04-06 09:00:00  1.208360e+11   411000.0
# ...

# %%
df["open"] +1
# Out:
# 2023-04-05 09:00:00    37207001.0
# 2023-04-06 09:00:00    37139001.0
# 2023-04-07 09:00:00    37058001.0
# 2023-04-08 09:00:00    36993001.0
# 2023-04-09 09:00:00    37064001.0
#                           ...
# 2023-10-17 09:00:00    38686001.0
# 2023-10-18 09:00:00    38652001.0
# 2023-10-19 09:00:00    38672001.0
# 2023-10-20 09:00:00    39000001.0
# 2023-10-21 09:00:00    40250001.0
# Name: open, Length: 200, dtype: float64

# %%
cond = df["close"] > df["open"]
df[cond]
# Out:
#                            open        high         low       close  \
# 2023-04-08 09:00:00  36993000.0  37249000.0  36930000.0  37080000.0
# 2023-04-09 09:00:00  37064000.0  37576000.0  36878000.0  37313000.0
# 2023-04-10 09:00:00  37331000.0  39183000.0  37255000.0  38985000.0
# 2023-04-11 09:00:00  38981000.0  40260000.0  38903000.0  40004000.0
# 2023-04-13 09:00:00  39694000.0  40198000.0  39689000.0  39911000.0
# ...                         ...         ...         ...         ...
# 2023-10-15 09:00:00  36790000.0  37189000.0  36659000.0  37086000.0
# 2023-10-16 09:00:00  37087000.0  40700000.0  37000000.0  38697000.0
# 2023-10-18 09:00:00  38652000.0  39380000.0  38479000.0  38710000.0
# 2023-10-19 09:00:00  38672000.0  39250000.0  38550000.0  39000000.0
# 2023-10-20 09:00:00  39000000.0  40700000.0  38820000.0  40250000.0
#
#                             value      range
# 2023-04-08 09:00:00  1.130097e+11   319000.0
# 2023-04-09 09:00:00  1.428535e+11   698000.0
# ...
